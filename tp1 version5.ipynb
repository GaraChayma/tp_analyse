# %% [markdown]
# # TP1 Analyse Numerique

# %% [markdown]
# ### Exercice 1:

# %% [markdown]
# ##### 1) Avec Matlab évaluer  𝑝(𝑥)  et  𝑓(𝑥)  pour  𝑥  allant de  .998  à  1.002  en choisissant des pas de  .0001 .

# %%
def f(x):
    return   x**6-6*x**5+15*x**4-20*x**3+15*x**2-6*x+1

# %%
def p(x):
    return (x-1)**6

# %%
p(0.998)
# Out:
# 6.400000000000034e-17

# %%
f(0.998)
# Out:
# 1.7763568394002505e-15

# %% [markdown]
# ##### p(x) et f(x) sont deux fonctions égaux mais ils n'ont pas les même résultats se qui montre que l'ordinateur ne fait pas le calcule correctement car l'ordinateur code seulement sur 32 ou 64 bits alors il va coder seulement une partie du nombre calculé il fait l'arrondit de cette valeur c'est l'erreur de codage d'où les valeurs calculer par l'ordinateur sont fausses

# %% [markdown]
# ### la méthode Horner

# %% [markdown]
# ##### si on remplace la valeur à calculer directement dans la fonction donc on va faire presque 26 opérations pour cette raison le mathématicien Horner utilise son algorithme pour calculer la valeur donnée avec la moitié des opérations utiliser

# %%
def horner(a,x):
    n=len(a)
    valeur=a[1]
    for i in range(2,n):
        valeur=valeur*x+a[i]
    return valeur

# %%
def f(x):
    return   x**6-6*x**5+15*x**4-20*x**3+15*x**2-6*x+1

# %%
def p(x):
    return (x-1)**6

# %%
T=[1,-6,15,-20,15,-6,1]
print(T)
print('--------------p(i)----------')
ii=[0.998,0.001,1.002]
for i in ii:
    print('ans=',p(i)) 
print('--------------f(i)----------')
ii=[0.998,0.001,1.002]
for i in ii:
    print('ans=',f(i)) 
print('----------horner---------')
ii=[0.998,0.001,1.002]
for i in ii:
    print('ans=',horner(T,i))
# Out:
# [1, -6, 15, -20, 15, -6, 1]
# --------------p(i)----------
# ans= 6.400000000000034e-17
# ans= 0.994014980014994
# ans= 6.400000000000034e-17
# --------------f(i)----------
# ans= 1.7763568394002505e-15
# ans= 0.994014980014994
# ans= 1.7763568394002505e-15
# ----------horner---------
# ans= -0.9880598402398078
# ans= 0.994014980014994
# ans= -1.0120601602401922

# %% [markdown]
# #### 2) Faire un graphique de  𝑓(𝑥)  et  𝑝(𝑥) . Commenter.

# %% [markdown]
# #### *représentation graphique de la fonction px

# %%
import matplotlib.pyplot as plt
import numpy as np
x1= np.arange(0.998,1.002,0.0001)
plt.xlabel("x")
plt.ylabel("px")
plt.grid(True)
plt.plot(x1,p(x1))

# %% [markdown]
# #### *représentation graphique de la fonction fx

# %%
import matplotlib.pyplot as plt
import numpy as np
x2= np.arange(0.998,1.002,0.0001)
plt.xlabel("x")
plt.ylabel("fx")
plt.grid(True)
plt.plot(x2,f(x2),color='r')
plt.plot(x1,p(x1),'*')

# %% [markdown]
# #### La représentation graphique de p(x) : plus clair , plus lisible  que celle de f(x)

# %% [markdown]
# ### Exercice 2:

# %% [markdown]
# #### On considère l'équation :k(𝑥)=𝑥3+𝑥2−3𝑥−3=0
# ### La fonction k(x)

# %%
def f(x):
    return  x**3+x**2-3*x-3

# %% [markdown]
# #### 1) Dessiner la courbe de  𝑓  dans l'intervalle  [−2;2] , puis trouver des intervalles convenables pour appliquer la méthode de >bisection.

# %%
import matplotlib.pyplot as plt
from numpy import linspace
f=lambda x: x**3+x**2-3*x-3
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))

# %% [raw]
#  D'aprés la representation graphique
#  il existe 3  intervalles convenables pour appliquer la méthode de >bisection.¶
#  alpha 1 ]-2 -1.5[
#  alpha 2 ]-1.5 1.5[
#  alpha 3 ]1.5 2[

# %% [markdown]
# #### 2) Utiliser un programme dicho.m qui permettra de trouver les solutions de l'équation  𝑓(𝑥)=0  avec  𝑒𝑝𝑠=0.001 .

# %%
import numpy as np
def madichotomie(ff,a,b):
    xg=a
    xd=b
    #en applique TVI entre a et b 
    for i in np.arange(100):
        xm=(xg+xd) / 2
        # en applique TVI entre xg et xm f(xg)etf(xm)sont de signe diff
        if f(xg)*f(xm) <0: 
            xd=xm
        else:
            xg=xm
    sol=(xg+xd)/2
    return sol

# %%
res=madichotomie(f,-2,-1.5)
res
# Out:
# -1.7320508075688772

# %%
f(-1.732177734375)
# Out:
# -0.00032194108644034714

# %%
res1=madichotomie(f,-1.5,1.5)
res1
# Out:
# -0.9999999999999998

# %%
res2=madichotomie(f,1.5,2)
res2
# Out:
# 1.7320508075688772

# %%
f(1.732177734375)
# Out:
# 0.0012013480154564604

# %% [markdown]
# ## 2éme methode dichotomie

# %%
def madichotomie(ff,a,b,e):
    xg=a
    xd=b
    while (xd-xg)>e:
        xm=(xg+xd) / 2
        if f(xg)*f(xm) >0:
            xg=xm
        else:
            xd=xm
    sol=(xg+xd)/2
    return sol

# %%
res=madichotomie(f,-2,-1.5,0.001)
res
# Out:
# -1.73193359375

# %% [markdown]
# #### 3) Modifier le programme dicho.m pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à  𝑒𝑝𝑠  près.

# %%
f=lambda x: x**3+x**2-3*x-3

# %%
import numpy as np
np.floor(2.3)
np.ceil(2.3)
# Out:
# 3.0

# %%
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+x**2-3*x-3

t=np.linspace(1.7,1.75,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# # Transformer le code précédent pour trouver desvaleurs approchées des solutions  𝛼1 ,  𝛼2  et  𝛼3  de l'equation (E

# %%
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x: x**3+x**2-3*x-3

t=np.linspace(-2,-1.5,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(-1.5,0.5,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'g')
plt.grid(True)
##########################################
t=np.linspace(0.5,1.5,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'b')
plt.grid(True)
#########################################
t=np.linspace(1,2,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# # EXERCICE 3

# %% [markdown]
# ### 1) Dessiner la courbe de  𝑓  dans l'intervalle  [1;2] , puis trouver une valeur approché de la solution à 0.001 près (En >utilisant la fonction zoom du graphique)

# %%
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+4*x**2-10

t=np.linspace(1,2,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# ### 2)Justification théorique pour la fonction g1

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
#
# a) $g(x)=\frac{1}{2}\sqrt{10-x^3}=x$.

# %% [markdown]
# $$x^3+4x^2-10=0$$
#
#  $$4x^2=10-x^3$$
#
#  $$2x=\sqrt{10-x^3}$$
#
#  $$x=\frac{1}{2}\sqrt{10-x^3}$$
#
# Donc $ f(x)=g(x)$

# %% [markdown]
# ## Calcul symbolique de la dérivée

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g1=lambda x: 1/2*sqrt(10-x**3)

# %%
dg1=lambdify(x,diff(g1(x),x,1))
dg1(1.365)
# Out:
# -0.5117446282927461

# %% [markdown]
# ## Que pouvez vous conclure à propos des convergences de g1

# %% [raw]
# g1 Diverge  car la valeur de g'(x)<L  telque L ∈]0, 1[ l=10365

# %% [markdown]
# ## Justification théoriques pour g2 et g3

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
#
# b) $g(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2=10$$
# $$x^2(x+4)=10$$
# $$x^2=\frac{10}{x+4}$$
# $$x=\sqrt{\displaystyle\frac{10}{4+x}}$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
# c) $g(x)=x-x^3-4x^2+10=x$.

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2-10+x-x=0$$
# $$x^3-4x^2+x-x=10$$
# $$x^3-4x^2+x=x+10$$
# $$4x^2+x=x-x^3+10$$
# $$x=x-x^3-4x^2+10$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# ### 3-  Ecrire puis appliquer une fonction Matlab que l'on appellera pointfixe.m aux trois schémas précédents en prenant >x0=1.5;eps=0.001

# %%
f=lambda x:  x**3+4*x**2-10 # la fonction f
g1=lambda x: 1/2*sqrt(10-x**3)
g2=lambda x: sqrt(10/(x+4))
g3=lambda x: x-x**3-4*x**2 + 10


def ptfixe(g,x0,eps,nmax):
    zero=x0
    for niter in range(1,nmax):
        x=zero
        zero=g(x) 
        erreur=abs(zero-x)
    return zero,erreur,niter
    if erreur<eps: 
        print('pas de convergence avec le nombre d''iteration indique')

# %%
ptfixe(g1,1.5,0.001,50)
# Out:
# (1.3652300134141, 2.44249065417534e-15, 49)

# %%
ptfixe(g2,1.5,0.001,50)
# Out:
# (1.3652300134141, 0, 49)

# %%
ptfixe(g3,1.5,0.001,50)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-181-88c9c8adf27b> in <module>
# ----> 1 ptfixe(g3,1.5,0.001,50)
#
# <ipython-input-178-cd67e70f2079> in ptfixe(g, x0, eps, nmax)
#       9     for niter in range(1,nmax):
#      10         x=zero
# ---> 11         zero=g(x)
#      12         erreur=abs(zero-x)
#      13     return zero,erreur,niter
#
# <ipython-input-178-cd67e70f2079> in <lambda>(x)
#       2 g1=lambda x: 1/2*sqrt(10-x**3)
#       3 g2=lambda x: sqrt(10/(x+4))
# ----> 4 g3=lambda x: x-x**3-4*x**2 + 10
#       5
#       6
#
# OverflowError: (34, 'Result too large')

# %% [markdown]
# 𝑔2 à 49  itérations g2 est la

# %% [markdown]
# 𝑔1 à 49 itérations

# %% [markdown]
# g3 est divergente
